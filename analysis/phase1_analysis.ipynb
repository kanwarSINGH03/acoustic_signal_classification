# %% [markdown]
# # Import Required Modules

# %%
import plotly.express as px
from sklearn.decomposition import PCA
import scipy.io as sio
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Load Data from matfile

# %%
phase1_data = sio.loadmat('../data/mine_impact_data_2019.mat')
print(phase1_data.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'mine', 'x', 'y'])

# %% [markdown]
# # Prepare Pandas Dataframe

# %%
df_x  = pd.DataFrame(phase1_data["x"].T)
df_y  = pd.DataFrame(phase1_data["y"].T, columns=["y"])
df_mine = pd.DataFrame(phase1_data["mine"].T, columns=["mine"])

df = pd.concat([df_x, df_y, df_mine], axis=1, join="inner")

df = df.dropna()

display(df)
# Out:
#                  0         1         2         3         4         5  \
# 0     6.420612e-04  0.000633  0.000670  0.000698  0.000701  0.000600
# 1     4.241467e-04  0.000389  0.000357  0.000275  0.000292  0.000398
# 2     6.834269e-04  0.000704  0.000699  0.000687  0.000640  0.000681
# 3    -5.584955e-04 -0.000551 -0.000609 -0.000610 -0.000565 -0.000661
# 4     7.988214e-04  0.000801  0.000856  0.000838  0.000846  0.000783
# ...            ...       ...       ...       ...       ...       ...
# 3304  1.330376e-04  0.000131  0.000008 -0.000098 -0.000104 -0.000230
# 3305 -2.276897e-05 -0.000009  0.000100  0.000051  0.000111  0.000186
# 3306  9.083748e-05 -0.000041 -0.000091 -0.000148 -0.000211 -0.000165
# 3307 -9.536743e-07 -0.000116 -0.000089 -0.000092 -0.000116 -0.000047
# 3308  1.734495e-04  0.000026  0.000145  0.000063  0.000086  0.000126
#
#              6         7         8         9  ...     35992     35993  \
# 0     0.000681  0.000659  0.000620  0.000591  ...  0.001969  0.001982
# 1     0.000435  0.000499  0.000531  0.000534  ...  0.001660  0.001608
# 2     0.000697  0.000672  0.000621  0.000615  ...  0.000784  0.000785
# 3    -0.000465 -0.000538 -0.000598 -0.000554  ... -0.000020 -0.000009
# 4     0.000760  0.000799  0.000845  0.000833  ...  0.000758  0.000798
# ...        ...       ...       ...       ...  ...       ...       ...
# 3304 -0.000071  0.000113  0.000143  0.000275  ...  0.000202  0.000195
# 3305  0.000232  0.000241  0.000159  0.000140  ...  0.000035  0.000009
# 3306 -0.000114 -0.000016  0.000076 -0.000026  ... -0.000093 -0.000066
# 3307 -0.000134  0.000015 -0.000057 -0.000111  ...  0.000167  0.000184
# 3308  0.000198  0.000231  0.000264  0.000378  ... -0.000003 -0.000010
#
#          35994     35995     35996     35997     35998     35999  y  mine
# 0     0.002026  0.002025  0.002084  0.002075  0.002127  0.002111  0     1
# 1     0.001603  0.001649  0.001621  0.001581  0.001594  0.001680  0     1
# 2     0.000791  0.000791  0.000867  0.000952  0.000950  0.000922  0     1
# 3    -0.000013  0.000010  0.000079  0.000041  0.000134  0.000170  0     1
# 4     0.000798  0.000824  0.000797  0.000851  0.000828  0.000918  0     1
# ...        ...       ...       ...       ...       ...       ... ..   ...
# 3304  0.000149  0.000053  0.000130  0.000085  0.000021  0.000029  0     5
# 3305  0.000116  0.000034  0.000073  0.000070  0.000050  0.000146  0     5
# 3306 -0.000094  0.000037  0.000025 -0.000050 -0.000195 -0.000179  0     5
# 3307  0.000231  0.000162  0.000164  0.000036  0.000082  0.000246  0     5
# 3308  0.000042 -0.000097 -0.000079 -0.000194 -0.000090 -0.000051  0     5
#
# [3309 rows x 36002 columns]

# %% [markdown]
# # Seperate features from the Dataframe
# ## Standardize data
# Mean = 0, Variance = 1
# ## PCA Analysis
# 1. 2 Component analysis
# 1. 3D Scatter plot giving z=-1 for label=0 and z=1 for label=1

# %%
X = df.iloc[:, :-2]
scaler = StandardScaler()
scaler.fit(X)
X = scaler.transform(X)
pca = PCA(n_components=2)

components = pca.fit_transform(X)

new_axis = phase1_data["y"].T.copy().astype(float)
new_axis[new_axis == 0] = -1

df_components = pd.DataFrame(components, columns=["PC1", "PC2"])
df_new_axis = pd.DataFrame( new_axis, columns=["z"])

df_kernel = pd.concat([df_components, df_new_axis], axis=1, join="inner")

one_count = np.sum(df_kernel["z"] == 1)
print("one_count", one_count)
zero_count = np.sum(df_kernel["z"] == -1)
print("zero_count", zero_count)

fig = px.scatter_3d(df_kernel, x="PC1", y="PC2", z="z", color=df['y'], hover_name=df['mine'],)
fig.show()
#save above scatter plot
fig.write_image("../assets/p1_pca_3d.png")
# Out:
# one_count 1097
# zero_count 2212

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

# %% [markdown]
# # Displaying how the waveform of both classes looks

# %%
example_0 = df.iloc[0, :-2].values
label_0 = df.iloc[0, -2]
sample_rate_phase1 = 48000

#Displaying 1st Waveform

plt.figure()
librosa.display.waveshow(example_0, sr=sample_rate_phase1)
plt.title('Waveform for label: {}'.format(label_0))
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.show()

#Displaying 2nd Waveform
example_1 = df[df['y'] == 1].iloc[0, :-2].values
label_1 = df[df['y'] == 1].iloc[0, -2]
plt.figure()
librosa.display.waveshow(example_1, sr=sample_rate_phase1)
plt.title('Waveform for label: {}'.format(label_1))
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.show()

# %% [markdown]
# # PCA analysis
# 1. Analysing how many components capture different amounts of variance in the features
# 1. Variance vs Number of Components Plot
# 1. Plot the components

# %%
# Assuming X is your data
pca = PCA(n_components=None)
pca.fit(X)

# Calculate cumulative explained variance
cumulative_variance = np.cumsum(pca.explained_variance_ratio_)

print("cumulative_variance:", cumulative_variance)

# Plot cumulative explained variance
plt.plot(range(1, len(cumulative_variance) + 1), cumulative_variance)
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Explained Variance vs. Number of Components')
plt.grid(True)
plt.show()

# Choose n_components based on the plot or a threshold
n_components = np.argmax(cumulative_variance >= 0.95) + 1
print(f'Number of components retaining 95% variance: {n_components}')

n_components = np.argmax(cumulative_variance >= 0.70) + 1
print(f'Number of components retaining 70% variance: {n_components}')

n_components = np.argmax(cumulative_variance >= 0.80) + 1
print(f'Number of components retaining 80% variance: {n_components}')
# Out:
# cumulative_variance: [0.05499683 0.10289899 0.14853799 ... 0.99999946 1.         1.        ]
# Number of components retaining 95% variance: 396
# Number of components retaining 70% variance: 48
# Number of components retaining 80% variance: 87

# %%
# Apply PCA with the selected number of components
pca_final = PCA(n_components=87)
X_reduced = pca_final.fit_transform(X)

df_pca_plot = pd.DataFrame(X_reduced, columns=[f"PC{i+1}" for i in range(87)])
plt.figure()
plt.plot(df_pca_plot, marker='o', linestyle='-')
plt.title('PCA Components')
plt.xlabel('Component Index')
plt.show()

# %% [markdown]
# # Listening to audio

# %%
from IPython.display import Audio

print("label", label_1)
Audio(example_1, rate=sample_rate_phase1)
# Out:
# label 1
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
